# %% [markdown]
# # 01 Text exploration
# Load the dataset and look at a few examples.

# %%
# !pip -q install -r ../requirements.txt

# %%
import pandas as pd

df = pd.read_csv('../data/raw/social_posts_synthetic.csv')
df.sample(6, random_state=7)

# %%
df['topic'].value_counts()
