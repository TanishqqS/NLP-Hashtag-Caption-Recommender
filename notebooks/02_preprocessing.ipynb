# %% [markdown]
# # 02 Preprocessing
# A light cleaner that keeps captions readable.

# %%
# !pip -q install -r ../requirements.txt

# %%
from src.preprocess import clean_text

examples = [
    'Sunset in Lisbon was unreal!!!',
    'Working on my dissertation: chapter 4',
    'New PR on deadlifts http://example.com',
]
for e in examples:
    print(e, '->', clean_text(e))

# %%
from src.data_loader import load_posts

df = load_posts('../data/raw/social_posts_synthetic.csv')
df[['caption','caption_clean','hashtags']].head(10)
