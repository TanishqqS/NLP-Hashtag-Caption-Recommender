# %% [markdown]
# # 04 Recommendation and evaluation
# Quick evaluation using precision and recall at k.

# %%
# !pip -q install -r ../requirements.txt

# %%
from src.evaluation import evaluate

metrics = evaluate('../data/raw/social_posts_synthetic.csv')
metrics.head()

# %%
metrics[['p_at_3','r_at_3','p_at_6','r_at_6']].mean()

# %%
import os
os.makedirs('../results', exist_ok=True)
metrics.to_csv('../results/eval_rows.csv', index=False)
print('Saved results/eval_rows.csv')
